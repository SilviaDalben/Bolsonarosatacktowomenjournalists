# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('/Users/silvinhad/Desktop/bertopic Python Analysis/veramagalhaes_tweets.csv').astype("string")
data.head(3)
# Out:
#                     id            author_id  \
# 0  1586870139936464897  1558969867126149127
# 1  1586870122764967937  1523457948399423488
# 2  1586869839230025728  1574540960608014345
#
#                                                 text edit_history_tweet_ids  \
# 0  RT @joaofilippe12: Hoje é o dia em que Mirian ...                   <NA>
# 1  RT @DaniMYGonzalez: Vera Magalhães bate boca c...                   <NA>
# 2  RT @saritacoelho: A imprensa inteira que se so...                   <NA>
#
#   possibly_sensitive in_reply_to_user_id                created_at  \
# 0              False                <NA>  2022-10-30T23:58:18.000Z
# 1              False                <NA>  2022-10-30T23:58:14.000Z
# 2              False                <NA>  2022-10-30T23:57:06.000Z
#
#   referenced_tweets      conversation_id lang retweet_count reply_count  \
# 0              <NA>  1586870139936464897   pt             1           0
# ...

# %%
data["created_at"] = pd.to_datetime(data["created_at"])

# %%
ts_1h = (
    data
    .set_index("created_at")
    .resample("h")
    .size()
    .reset_index(name="count")
)

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

plt.figure(figsize=(14, 5))
plt.plot(ts_1h["created_at"], ts_1h["count"])
plt.xlabel("Date")
plt.ylabel("Number of tweets")
plt.title("Tweet Volume Per Hour Mentioning Vera Magalhães")
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

plt.figure(figsize=(14, 5))
plt.plot(ts_1h["created_at"], ts_1h["count"])
plt.xlabel("Date")
plt.ylabel("Number of tweets")
plt.title("Tweet Volume Per Hour Mentioning Vera Magalhães")

# 🔑 set x-axis ticks every 10 days
plt.gca().xaxis.set_major_locator(mdates.DayLocator(interval=10))
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter("%Y-%m-%d"))

plt.xticks(rotation=45)
plt.tight_layout()

plt.show()
