# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('/Users/silvinhad/Desktop/bertopic Python Analysis/amandaklein_tweets.csv').astype("string")
data.head(3)
# Out:
#                     id   author_id  \
# 0  1586860768519135234  2466911024
# 1  1586813481021571075   305352481
# 2  1586810950224691207     9921902
#
#                                                 text edit_history_tweet_ids  \
# 0  @JovemPanNews A parcialidade de vocês me faz n...                   <NA>
# 1  @JoaoGSiilva @DaniAlvesD2 A federal pegos a pe...                   <NA>
# 2  A jovem pan já pode mandar embora a Amanda Kle...                   <NA>
#
#   possibly_sensitive in_reply_to_user_id                created_at  \
# 0              False         106175018.0  2022-10-30T23:21:04.000Z
# 1              False          39920309.0  2022-10-30T20:13:10.000Z
# 2              False                <NA>  2022-10-30T20:03:06.000Z
#
#   referenced_tweets      conversation_id lang retweet_count reply_count  \
# 0              <NA>  1586855631922909185   pt             0           0
# 1              <NA>  1586773724031754243   pt             0           0
# ...

# %%
data["created_at"] = pd.to_datetime(data["created_at"])

# %%
ts_1h = (
    data
    .set_index("created_at")
    .resample("h")
    .size()
    .reset_index(name="count")
)

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

plt.figure(figsize=(14, 5))
plt.plot(ts_1h["created_at"], ts_1h["count"])
plt.xlabel("Date")
plt.ylabel("Number of tweets")
plt.title("Tweet Volume Per Hour Mentioning Amanda Klein")
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

plt.figure(figsize=(14, 5))
plt.plot(ts_1h["created_at"], ts_1h["count"])
plt.xlabel("Date")
plt.ylabel("Number of tweets")
plt.title("Tweet Volume Per Hour Mentioning Amanda Klein")

# 🔑 set x-axis ticks every 10 days
plt.gca().xaxis.set_major_locator(mdates.DayLocator(interval=10))
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter("%Y-%m-%d"))

plt.xticks(rotation=45)
plt.tight_layout()

plt.show()
